# %% [markdown]
# # 🌌 Topic 3: Elbow Method
#
# **Summary:** WCSS calculation and finding the optimal K using the Elbow Method and Silhouette Score.
#
# ---

# %% [markdown]
# ## 📝 Core Concepts & Explanations
#
# ### Finding Optimal K: The Elbow Method
# We calculate the **Within-Cluster Sum of Squares (WCSS)** (also called Inertia) for different values of $K$. As $K$ increases, WCSS decreases.
# The optimal $K$ is often at the 'elbow' of the curve, where adding more clusters yields diminishing returns in variance reduction.

# %% [markdown]
# ## 💻 Code Demonstration
# Run the cells below to see the concepts in action:

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_score
import warnings
warnings.filterwarnings('ignore')

X, _ = make_blobs(n_samples=500, centers=5, cluster_std=0.8, random_state=42)

wcss = []
silhouettes = []
K_range = range(2, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
    silhouettes.append(silhouette_score(X, kmeans.labels_))

fig, ax1 = plt.subplots(figsize=(8, 4))

ax1.plot(K_range, wcss, 'bo-')
ax1.set_xlabel('Number of clusters K')
ax1.set_ylabel('WCSS (Inertia)', color='b')

ax2 = ax1.twinx()
ax2.plot(K_range, silhouettes, 'rs-')
ax2.set_ylabel('Silhouette Score', color='r')

plt.title('Elbow Method and Silhouette Score')
plt.show()

# %% [markdown]
# ### Exercises
# 1. What does a high Silhouette Score indicate?

# %%
print('A high Silhouette Score (close to 1) indicates that the object is well matched to its own cluster and poorly matched to neighboring clusters. It is often a more reliable metric than the Elbow method.')
# Out:
# A high Silhouette Score (close to 1) indicates that the object is well matched to its own cluster and poorly matched to neighboring clusters. It is often a more reliable metric than the Elbow method.
