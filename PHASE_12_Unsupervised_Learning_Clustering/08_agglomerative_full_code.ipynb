# %% [markdown]
# # 🌌 Topic 8: Agglomerative full code
#
# **Summary:** Scikit-Learn implementation of Hierarchical clustering with Dendrogram plotting.
#
# ---

# %% [markdown]
# ## 📝 Core Concepts & Explanations
#
# ### Dendrograms
# A dendrogram is a tree-like diagram that records the sequences of merges.
# The y-axis represents the distance at which two clusters were merged. The optimal number of clusters is usually found by finding the tallest vertical line that can be drawn without crossing any horizontal merge lines.

# %% [markdown]
# ## 💻 Code Demonstration
# Run the cells below to see the concepts in action:

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.datasets import make_blobs

X, _ = make_blobs(n_samples=30, centers=3, random_state=42)

# Scipy provides excellent dendrogram plotting tools
Z = linkage(X, method='ward')

plt.figure(figsize=(10, 5))
plt.title('Hierarchical Clustering Dendrogram (Ward Linkage)')
plt.xlabel('Sample index')
plt.ylabel('Distance')
dendrogram(Z, leaf_rotation=90., leaf_font_size=8.)
plt.axhline(y=15, color='r', linestyle='--') # Cutting the tree
plt.show()

# %% [markdown]
# ### Exercises
# 1. What does the 'Ward' linkage method minimize?

# %%
print('Ward linkage minimizes the total within-cluster variance. At each step, it merges the pair of clusters that leads to the minimum increase in total within-cluster sum of squares (WCSS), making it very similar in objective to K-Means.')
# Out:
# Ward linkage minimizes the total within-cluster variance. At each step, it merges the pair of clusters that leads to the minimum increase in total within-cluster sum of squares (WCSS), making it very similar in objective to K-Means.
