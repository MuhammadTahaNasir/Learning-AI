# %% [markdown]
# # 📉 Topic 16: Learning Rate
#
# **Summary:** Influence of learning rate on gradient descent convergence.
#
# ---

# %% [markdown]
# ## 📝 Core Concepts & Explanations
#
# ### Hyperparameter: Learning Rate ($\alpha$)
# - Too small: very slow convergence.
# - Too large: divergence, cost increases, oscillation.

# %% [markdown]
# ## 💻 Code Demonstration
# Run the cells below to see the concepts in action:

# %%
import numpy as np

x_start = 10.0

def run_gd(lr, epochs=5):
    x = x_start
    history = []
    for _ in range(epochs):
        grad = 2*x
        x = x - lr * grad
        history.append(x)
    return history

print('Optimal LR (0.1):', run_gd(0.1))
print('Diverging LR (1.1):', run_gd(1.1))
# Out:
# Optimal LR (0.1): [8.0, 6.4, 5.12, 4.096, 3.2768]
# Diverging LR (1.1): [-12.0, 14.400000000000002, -17.280000000000005, 20.736000000000008, -24.883200000000013]

# %% [markdown]
# ### Exercises
# 1. Run GD with a very small learning rate (0.001) for 5 epochs and observe progress.

# %%
print('Very small LR (0.001):', run_gd(0.001))
# Out:
# Very small LR (0.001): [9.98, 9.960040000000001, 9.94011992, 9.92023968016, 9.90039920079968]
